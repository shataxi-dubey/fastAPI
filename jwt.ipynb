# %%
import jwt
from datetime import datetime, timedelta, timezone

SECRET_KEY = "c4d7faee7cd8ae6cbcbd86ec7333ace813af2916c749738c7bcfac2012ea29fb"
ALGORITHM = "HS256"
ACCESS_TOKEN_EXPIRE_MINUTES = 30

# %%
def create_access_token(data: dict, expires_delta: timedelta | None = None):
    to_encode = data.copy()
    if expires_delta:
        expire = datetime.now(timezone.utc) + expires_delta
    else:
        expire = datetime.now(timezone.utc) + timedelta(minutes=15)
    to_encode.update({"exp": expire})
    encoded_jwt = jwt.encode(to_encode, SECRET_KEY, algorithm=ALGORITHM)
    return encoded_jwt

# %%
token = create_access_token(data = {"sub":"johndoe"}, expires_delta = timedelta(minutes=ACCESS_TOKEN_EXPIRE_MINUTES))
token
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJqb2huZG9lIiwiZXhwIjoxNzU0NTQ0MDgwfQ.-HE2C_Wprrdv0ykkhlYS4O4rHI2UriVcdHh_PAYGICQ'

# %%
token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJqb2huZG9lIiwiZXhwIjoxNzU0NTQ0NzQwfQ.bBppnyi2QctQgE0kkv2zYEIrcMf92ULcjVQLJEVqZuQ'
SECRET_KEY = 'd6aaa61a1b1cbc4caec4d19640775b27b3f90112fc814e7e76d1dcae841260e9'

# %%
payload = jwt.decode(token, SECRET_KEY, algorithms=[ALGORITHM])
print(payload)
username = payload.get("sub")
print(username)
# Out:
# {'sub': 'johndoe', 'exp': 1754544740}
# johndoe
